# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import seaborn as sns
import scanpy as sc
from glob import iglob
import anndata
#import scrublet as scr # requires 'pip install scrublet'
import os
import sklearn
from sklearn.linear_model import LogisticRegression
import matplotlib as mpl
import scipy
import matplotlib.pyplot as plt
import pickle

# %%
np.random.seed(0)

# %%
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80)  # low dpi (dots per inch) yields small inline figures
# Out:
# -----
# anndata     0.8.0
# scanpy      1.9.1
# -----
# PIL                         9.0.1
# asttokens                   NA
# backcall                    0.2.0
# beta_ufunc                  NA
# binom_ufunc                 NA
# bottleneck                  1.3.4
# cffi                        1.15.0
# cloudpickle                 2.0.0
# colorama                    0.4.4
# cycler                      0.10.0
# cython_runtime              NA
# cytoolz                     0.11.0
# dask                        2022.02.1
# dateutil                    2.8.2
# debugpy                     1.5.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# executing                   0.8.3
# fsspec                      2022.02.0
# google                      NA
# h5py                        3.6.0
# ipykernel                   6.9.1
# ipython_genutils            0.2.0
# ipywidgets                  7.6.5
# jedi                        0.18.1
# jinja2                      2.11.3
# joblib                      1.1.0
# jupyter_server              1.13.5
# kiwisolver                  1.3.2
# llvmlite                    0.38.0
# markupsafe                  2.0.1
# matplotlib                  3.5.1
# matplotlib_inline           NA
# mkl                         2.4.0
# mpl_toolkits                NA
# natsort                     8.1.0
# nbinom_ufunc                NA
# nt                          NA
# ntsecuritycon               NA
# numba                       0.55.1
# numexpr                     2.8.1
# numpy                       1.21.5
# packaging                   21.3
# pandas                      1.4.2
# parso                       0.8.3
# pickleshare                 0.7.5
# pkg_resources               NA
# prompt_toolkit              3.0.20
# psutil                      5.8.0
# pure_eval                   0.2.2
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.6.0
# pydevd_concurrency_analyser NA
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.11.2
# pyparsing                   3.0.4
# pythoncom                   NA
# pytz                        2021.3
# pywintypes                  NA
# scipy                       1.7.3
# seaborn                     0.11.2
# session_info                1.0.0
# setuptools                  61.2.0
# six                         1.16.0
# sklearn                     1.0.2
# snappy                      NA
# sphinxcontrib               NA
# stack_data                  0.2.0
# statsmodels                 0.13.2
# tblib                       1.7.0
# threadpoolctl               2.2.0
# tlz                         0.11.0
# toolz                       0.11.2
# tornado                     6.1
# traitlets                   5.1.1
# typing_extensions           NA
# wcwidth                     0.2.5
# win32api                    NA
# win32com                    NA
# win32security               NA
# yaml                        6.0
# zipp                        NA
# zmq                         22.3.0
# zope                        NA
# -----
# IPython             8.2.0
# jupyter_client      6.1.12
# jupyter_core        4.9.2
# jupyterlab          3.3.2
# notebook            6.4.8
# -----
# Python 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]
# Windows-10-10.0.19042-SP0
# -----
# Session information updated at 2022-06-16 09:09

# %% [markdown]
# # Load in the data

# %%
Tissue ={}
Tissue['GSM5004180_PT1'] = 'Gastric'
Tissue['GSM5004181_PT2'] = 'Gastric'
Tissue['GSM5004182_PT3'] = 'Gastric'

Tissue['GSM5004183_NT1'] = 'Normal'
Tissue['GSM5004184_LN1'] = 'Lymph node'
Tissue['GSM5004185_LN2'] = 'Lymph node'
Tissue['GSM5004187_P1'] = 'Peritoneum'
Tissue['GSM5004188_Li1'] = 'Liver'
Tissue['GSM5004189_Li2'] = 'Liver'

metastasis_status = {}
metastasis_status['GSM5004180_PT1'] = 'Primary'
metastasis_status['GSM5004181_PT2'] = 'Primary'
metastasis_status['GSM5004182_PT3'] = 'Primary'

metastasis_status['GSM5004183_NT1'] = 'Normal'
metastasis_status['GSM5004184_LN1'] = 'Metastasis'
metastasis_status['GSM5004185_LN2'] = 'Metastasis'
metastasis_status['GSM5004187_P1'] = 'Metastasis'
metastasis_status['GSM5004188_Li1'] = 'Metastasis'
metastasis_status['GSM5004189_Li2'] = 'Metastasis'

# %%
# %%time
import os
holder = []
path = './00.data/'
files = os.listdir(path)
for file in files:
    file_dir = os.path.join(path,file)
    print("开始处理：",file)
    holder.append(sc.read_10x_mtx(file_dir,var_names= 'gene_symbols',cache=True))
    holder[-1].var_names_make_unique()
     # Filer cells with less than 200 genes expressed
    sc.pp.filter_cells(holder[-1], min_genes=200)
    
    # Filer genes expressed in less than 3 cells
    sc.pp.filter_genes(holder[-1], min_cells=3)
    ##add metadata
    holder[-1].obs['ID'] = file.split('_')[0]
    holder[-1].obs['Sample'] = file.split('_')[1]
    info = Tissue[file]
    holder[-1].obs['Tissue'] = info
    stau = metastasis_status[file]
    holder[-1].obs['metastasis_status'] = stau
    ##add percent_mito
    mito_genes = [name for name in holder[-1].var_names if name.startswith('MT-')]
    holder[-1].obs['percent_mito'] = np.sum(
        holder[-1][:, mito_genes].X, axis=1).A1 / np.sum(holder[-1].X, axis=1).A1
# Out:
# 开始处理： GSM5004180_PT1
# ... reading from cache file cache\00.data-GSM5004180_PT1-matrix.h5ad
# filtered out 26 cells that have less than 200 genes expressed
# filtered out 12306 genes that are detected in less than 3 cells
# 开始处理： GSM5004181_PT2
# ... reading from cache file cache\00.data-GSM5004181_PT2-matrix.h5ad
# filtered out 54 cells that have less than 200 genes expressed
# filtered out 11264 genes that are detected in less than 3 cells
# 开始处理： GSM5004182_PT3
# ... reading from cache file cache\00.data-GSM5004182_PT3-matrix.h5ad
# filtered out 208 cells that have less than 200 genes expressed
# filtered out 13050 genes that are detected in less than 3 cells
# 开始处理： GSM5004183_NT1
# ... reading from cache file cache\00.data-GSM5004183_NT1-matrix.h5ad
# filtered out 145 cells that have less than 200 genes expressed
# filtered out 14364 genes that are detected in less than 3 cells
# 开始处理： GSM5004184_LN1
# ... reading from cache file cache\00.data-GSM5004184_LN1-matrix.h5ad
# filtered out 37 cells that have less than 200 genes expressed
# filtered out 13742 genes that are detected in less than 3 cells
# 开始处理： GSM5004185_LN2
# ... reading from cache file cache\00.data-GSM5004185_LN2-matrix.h5ad
# filtered out 44 cells that have less than 200 genes expressed
# filtered out 13154 genes that are detected in less than 3 cells
# 开始处理： GSM5004187_P1
# ... reading from cache file cache\00.data-GSM5004187_P1-matrix.h5ad
# filtered out 149 cells that have less than 200 genes expressed
# filtered out 10674 genes that are detected in less than 3 cells
# 开始处理： GSM5004188_Li1
# ... reading from cache file cache\00.data-GSM5004188_Li1-matrix.h5ad
# filtered out 7 cells that have less than 200 genes expressed
# filtered out 16343 genes that are detected in less than 3 cells
# 开始处理： GSM5004189_Li2
# ... reading from cache file cache\00.data-GSM5004189_Li2-matrix.h5ad
# filtered out 60 cells that have less than 200 genes expressed
# filtered out 12687 genes that are detected in less than 3 cells
# CPU times: total: 3.67 s
# Wall time: 4.02 s

# %%
# %%time
adata = holder[0].concatenate(holder[1:],join='outer',index_unique=None)
adata.X = adata.X.tocsr()
# Out:
# D:\conda\lib\site-packages\anndata\_core\anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# D:\conda\lib\site-packages\anndata\_core\anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# D:\conda\lib\site-packages\anndata\_core\anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# CPU times: total: 1.14 s
# Wall time: 1.17 s

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 48020 × 25444
#     obs: 'n_genes', 'ID', 'Sample', 'Tissue', 'metastasis_status', 'percent_mito', 'batch'
#     var: 'gene_ids-0', 'feature_types-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'n_cells-7', 'gene_ids-8', 'feature_types-8', 'n_cells-8'

# %%
adata.obs['n_counts'] = adata.X.sum(1)
adata.obs['log_counts'] = np.log(adata.obs['n_counts'])
adata.obs['n_genes'] = (adata.X > 0).sum(1)

# %%
adata.obs
# Out:
#                     n_genes          ID Sample   Tissue metastasis_status  \
# AAACCCACAACAACAA-1      352  GSM5004180    PT1  Gastric           Primary
# AAACCCAGTCAAAGTA-1     4415  GSM5004180    PT1  Gastric           Primary
# AAACCCAGTGGATACG-1      492  GSM5004180    PT1  Gastric           Primary
# AAACCCATCGTTCCCA-1      323  GSM5004180    PT1  Gastric           Primary
# AAACGAAAGCTGTTCA-1      771  GSM5004180    PT1  Gastric           Primary
# ...                     ...         ...    ...      ...               ...
# TTTGTTGTCGCGCTGA-1     1068  GSM5004189    Li2    Liver        Metastasis
# TTTGTTGTCGGACTGC-1      316  GSM5004189    Li2    Liver        Metastasis
# TTTGTTGTCGTAGGAG-1     1034  GSM5004189    Li2    Liver        Metastasis
# TTTGTTGTCTAGAACC-1     1186  GSM5004189    Li2    Liver        Metastasis
# TTTGTTGTCTTTCCGG-1     1397  GSM5004189    Li2    Liver        Metastasis
#
#                     percent_mito batch  n_counts  log_counts
# AAACCCACAACAACAA-1      0.008205     0     975.0    6.882438
# AAACCCAGTCAAAGTA-1      0.076083     0   16022.0    9.681718
# AAACCCAGTGGATACG-1      0.009602     0    1458.0    7.284821
# AAACCCATCGTTCCCA-1      0.009579     0     522.0    6.257668
# AAACGAAAGCTGTTCA-1      0.005300     0    2264.0    7.724888
# ...                          ...   ...       ...         ...
# TTTGTTGTCGCGCTGA-1      0.086989     8    2667.0    7.888710
# TTTGTTGTCGGACTGC-1      0.310109     8     732.0    6.595780
# TTTGTTGTCGTAGGAG-1      0.043174     8    2432.0    7.796469
# TTTGTTGTCTAGAACC-1      0.054685     8    2615.0    7.869020
# TTTGTTGTCTTTCCGG-1      0.069156     8    3615.0    8.192847
#
# [48020 rows x 9 columns]

# %%
adata.var
# Out:
#                gene_ids-0  feature_types-0  n_cells-0       gene_ids-1  \
# A1BG      ENSG00000121410  Gene Expression      224.0  ENSG00000121410
# A1BG-AS1  ENSG00000268895  Gene Expression       34.0  ENSG00000268895
# A1CF      ENSG00000148584  Gene Expression       56.0  ENSG00000148584
# A2M       ENSG00000175899  Gene Expression       91.0  ENSG00000175899
# A2M-AS1   ENSG00000245105  Gene Expression       33.0  ENSG00000245105
# ...                   ...              ...        ...              ...
# ZXDC      ENSG00000070476  Gene Expression      205.0  ENSG00000070476
# ZYG11A    ENSG00000203995  Gene Expression       43.0  ENSG00000203995
# ZYG11B    ENSG00000162378  Gene Expression      408.0  ENSG00000162378
# ZYX       ENSG00000159840  Gene Expression     1230.0  ENSG00000159840
# ZZEF1     ENSG00000074755  Gene Expression      509.0  ENSG00000074755
#
#           feature_types-1  n_cells-1       gene_ids-2  feature_types-2  \
# A1BG      Gene Expression      384.0  ENSG00000121410  Gene Expression
# A1BG-AS1  Gene Expression       70.0  ENSG00000268895  Gene Expression
# A1CF      Gene Expression       11.0  ENSG00000148584  Gene Expression
# A2M       Gene Expression     1059.0  ENSG00000175899  Gene Expression
# A2M-AS1   Gene Expression      103.0  ENSG00000245105  Gene Expression
# ...                   ...        ...              ...              ...
# ZXDC      Gene Expression      779.0  ENSG00000070476  Gene Expression
# ZYG11A    Gene Expression        9.0  ENSG00000203995  Gene Expression
# ZYG11B    Gene Expression     1766.0  ENSG00000162378  Gene Expression
# ZYX       Gene Expression     3189.0  ENSG00000159840  Gene Expression
# ZZEF1     Gene Expression     1809.0  ENSG00000074755  Gene Expression
#
#           n_cells-2       gene_ids-3  ... n_cells-5       gene_ids-6  \
# A1BG          379.0  ENSG00000121410  ...    1572.0  ENSG00000121410
# A1BG-AS1       41.0  ENSG00000268895  ...     263.0  ENSG00000268895
# A1CF           24.0  ENSG00000148584  ...       NaN  ENSG00000148584
# A2M            90.0  ENSG00000175899  ...      69.0  ENSG00000175899
# A2M-AS1        46.0  ENSG00000245105  ...      67.0  ENSG00000245105
# ...             ...              ...  ...       ...              ...
# ZXDC          215.0  ENSG00000070476  ...     463.0  ENSG00000070476
# ZYG11A         12.0  ENSG00000203995  ...      17.0  ENSG00000203995
# ZYG11B        378.0  ENSG00000162378  ...     492.0  ENSG00000162378
# ZYX           596.0  ENSG00000159840  ...    1075.0  ENSG00000159840
# ZZEF1         724.0  ENSG00000074755  ...     923.0  ENSG00000074755
#
#           feature_types-6 n_cells-6       gene_ids-7  feature_types-7  \
# A1BG      Gene Expression     826.0  ENSG00000121410  Gene Expression
# A1BG-AS1  Gene Expression     127.0  ENSG00000268895  Gene Expression
# A1CF      Gene Expression      61.0  ENSG00000148584  Gene Expression
# A2M       Gene Expression     590.0  ENSG00000175899  Gene Expression
# A2M-AS1   Gene Expression      85.0  ENSG00000245105  Gene Expression
# ...                   ...       ...              ...              ...
# ZXDC      Gene Expression     508.0  ENSG00000070476  Gene Expression
# ZYG11A    Gene Expression      27.0              NaN              NaN
# ZYG11B    Gene Expression     786.0  ENSG00000162378  Gene Expression
# ZYX       Gene Expression    1303.0  ENSG00000159840  Gene Expression
# ZZEF1     Gene Expression    1078.0  ENSG00000074755  Gene Expression
#
#          n_cells-7       gene_ids-8  feature_types-8 n_cells-8
# A1BG         120.0  ENSG00000121410  Gene Expression    1147.0
# A1BG-AS1      36.0  ENSG00000268895  Gene Expression     168.0
# A1CF          15.0  ENSG00000148584  Gene Expression       9.0
# A2M          233.0  ENSG00000175899  Gene Expression     829.0
# A2M-AS1      214.0  ENSG00000245105  Gene Expression    1707.0
# ...            ...              ...              ...       ...
# ZXDC         125.0  ENSG00000070476  Gene Expression     614.0
# ZYG11A         NaN  ENSG00000203995  Gene Expression      11.0
# ZYG11B       105.0  ENSG00000162378  Gene Expression     697.0
# ZYX          254.0  ENSG00000159840  Gene Expression    1936.0
# ZZEF1        333.0  ENSG00000074755  Gene Expression    1606.0
#
# [25444 rows x 27 columns]

# %% [markdown]
# # 保存scanpy.h5ad用于后续使用

# %%
adata.write('./cache/scRNA_merge.h5ad')
