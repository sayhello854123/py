# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
##load all packages
import anndata
import collections
import numpy as np
import pandas as pd
import scanpy as sc
import MACA as maca
import seaborn as sns
from glob import iglob
import scrublet as scr
import scanpy.external as sce
import scvelo as scv
#import scrublet as scr # requires 'pip install scrublet'
import os
import sklearn
import bbknn
from sklearn.linear_model import LogisticRegression
import matplotlib as mpl
import scipy
import matplotlib.pyplot as plt
import pickle

import warnings
warnings.filterwarnings("ignore")
np.random.seed(0)
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80,dpi_save=800)  # low dpi (dots per inch) yields small inline figures
# Out:
# -----
# anndata     0.8.0
# scanpy      1.9.1
# -----
# MACA                        NA
# PIL                         9.0.1
# annoy                       NA
# asttokens                   NA
# backcall                    0.2.0
# bbknn                       NA
# beta_ufunc                  NA
# binom_ufunc                 NA
# bottleneck                  1.3.4
# cairo                       1.21.0
# cffi                        1.15.0
# cloudpickle                 2.0.0
# colorama                    0.4.4
# cycler                      0.10.0
# cython_runtime              NA
# cytoolz                     0.11.0
# dask                        2022.02.1
# dateutil                    2.8.2
# debugpy                     1.5.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# executing                   0.8.3
# fsspec                      2022.02.0
# google                      NA
# h5py                        3.6.0
# igraph                      0.9.11
# ipykernel                   6.9.1
# ipython_genutils            0.2.0
# ipywidgets                  7.6.5
# jedi                        0.17.2
# jinja2                      2.11.3
# joblib                      1.1.0
# jupyter_server              1.13.5
# kiwisolver                  1.3.2
# leidenalg                   0.8.10
# llvmlite                    0.38.0
# markupsafe                  2.0.1
# matplotlib                  3.5.1
# matplotlib_inline           NA
# mkl                         2.4.0
# mpl_toolkits                NA
# natsort                     8.1.0
# nbinom_ufunc                NA
# nt                          NA
# ntsecuritycon               NA
# numba                       0.55.1
# numexpr                     2.8.1
# numpy                       1.21.5
# packaging                   21.3
# pandas                      1.4.2
# parso                       0.7.1
# pickleshare                 0.7.5
# pkg_resources               NA
# prompt_toolkit              3.0.20
# psutil                      5.8.0
# pure_eval                   0.2.2
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.6.0
# pydevd_concurrency_analyser NA
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.11.2
# pynndescent                 0.5.7
# pyparsing                   3.0.4
# pythoncom                   NA
# pytz                        2021.3
# pywintypes                  NA
# scipy                       1.7.3
# scrublet                    NA
# scvelo                      0.2.4
# seaborn                     0.11.2
# session_info                1.0.0
# setuptools                  61.2.0
# setuptools_scm              NA
# six                         1.16.0
# sklearn                     1.0.2
# snappy                      NA
# sphinxcontrib               NA
# stack_data                  0.2.0
# statsmodels                 0.13.2
# tblib                       1.7.0
# texttable                   1.6.4
# threadpoolctl               2.2.0
# tlz                         0.11.0
# toolz                       0.11.2
# tornado                     6.1
# tqdm                        4.64.0
# traitlets                   5.1.1
# typing_extensions           NA
# umap                        0.5.3
# wcwidth                     0.2.5
# win32api                    NA
# win32com                    NA
# win32security               NA
# yaml                        6.0
# zipp                        NA
# zmq                         22.3.0
# zope                        NA
# -----
# IPython             8.2.0
# jupyter_client      6.1.12
# jupyter_core        4.9.2
# jupyterlab          3.3.2
# notebook            6.4.8
# -----
# Python 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]
# Windows-10-10.0.19044-SP0
# -----
# Session information updated at 2022-07-06 14:46

# %%
adata = sc.read_h5ad('./cache/scRNA_qc.h5ad')
mac2 = sc.read_h5ad('./cache/scRNA_cnv.h5ad')
mac1=mac2[mac2.obs['cell type'].isin(['Monocytes'])]
mac=adata[adata.obs.index.isin(mac1.obs.index)]

# %%
sc.pp.normalize_total(mac, target_sum=1e4)
sc.pp.log1p(mac)
sc.tl.pca(mac, svd_solver='arpack')
sc.pl.pca_variance_ratio(mac, log=True,n_pcs = 50)
sns.lineplot(data = mac.uns['pca']['variance_ratio'],palette= 'tab10',linewidth = 3)
mac.uns['pca']['variance']
sns.lineplot(data =mac.uns['pca']['variance'],palette='tab10',linewidth = 3)
# Out:
# normalizing counts per cell
#     finished (0:00:00)
# WARNING: adata.X seems to be already log-transformed.
# computing PCA
#     with n_comps=50
#     finished (0:00:03)
# <AxesSubplot:>

# %%
for i in range(10,90,5):
    sc.pp.neighbors(mac,n_pcs=20, n_neighbors= i)
    sc.tl.umap(mac)
    print(f'neighbors的数值为：{i}')
    sc.pl.umap(mac)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:01)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:01)
# neighbors的数值为：10
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:01)
# neighbors的数值为：15
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:02)
# neighbors的数值为：20
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:02)
# neighbors的数值为：25
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:02)
# neighbors的数值为：30
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:02)
# neighbors的数值为：35
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:02)
# neighbors的数值为：40
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:02)
# neighbors的数值为：45
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:02)
# neighbors的数值为：50
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:02)
# neighbors的数值为：55
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:02)
# neighbors的数值为：60
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:02)
# neighbors的数值为：65
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:02)
# neighbors的数值为：70
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:03)
# neighbors的数值为：75
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:02)
# neighbors的数值为：80
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:03)
# neighbors的数值为：85

# %%
sc.pp.neighbors(mac,n_pcs=40, n_neighbors= 70)
sc.tl.umap(mac)
sc.pl.umap(mac)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 40
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:02)

# %%
for i in range(1,16):
    sc.tl.leiden(mac,resolution=round(i*0.1,1),key_added=f'cluster_{round(i*0.1,1)}')
# Out:
# running Leiden clustering
#     finished: found 4 clusters and added
#     'cluster_0.1', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 6 clusters and added
#     'cluster_0.2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 6 clusters and added
#     'cluster_0.3', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 8 clusters and added
#     'cluster_0.4', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 8 clusters and added
#     'cluster_0.5', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 9 clusters and added
#     'cluster_0.6', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 10 clusters and added
#     'cluster_0.7', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 10 clusters and added
#     'cluster_0.8', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 11 clusters and added
#     'cluster_0.9', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 11 clusters and added
#     'cluster_1.0', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 12 clusters and added
#     'cluster_1.1', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 12 clusters and added
#     'cluster_1.2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 14 clusters and added
#     'cluster_1.3', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 14 clusters and added
#     'cluster_1.4', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 14 clusters and added
#     'cluster_1.5', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
sc.pl.umap(mac,color = [f'cluster_{round(i*0.1,1)}' for i in range(1,16)],ncols = 3,save='mac_allcluster.pdf')
# Out:
# WARNING: saving figure to file figures\umapmac_allcluster.pdf

# %%
sc.tl.rank_genes_groups(mac,'cluster_0.8',method='wilcoxon')
sc.pl.rank_genes_groups(mac, n_genes=25, sharey=False)
# Out:
# ranking genes
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:02)

# %%
pd.DataFrame(mac.uns['rank_genes_groups']['names']).head(10)
# Out:
#           0       1       2      3         4         5       6        7  \
# 0   SLCO2B1   RPLP1  IFITM3  ADAP2     PTGS2  HLA-DQA2  SLC2A3    FSCN1
# 1      ACP5  EEF1A1    CYBB    A2M      IL1B      JAML   NEAT1     CCR7
# 2      PLD3  TMSB4X    CALR    JUN   ATP13A3    RPL36A    MCL1    LAMP3
# 3     MMP14    TPT1  SLC8A1   MAFB  SERPINB9    EEF1B2    VCAN    BIRC3
# 4     GPNMB     B2M    LAP3  DDX3Y      EHD1     RPS10   NAMPT  POGLUT1
# 5    SPRED1    FTH1    RETN    DST      ETS2    LGALS2    FCN1    DAPP1
# 6    LHFPL2    ACTB    OLR1   EGR1      KYNU   SLC38A1  JMJD1C     STK4
# 7  SERPING1  TMSB10    XIST   LIPA     TIMP1     NDRG2    SKIL    RFTN1
# 8     CD163     FTL  PLXDC2   APOE     NFKB1      RPL4    SRGN    CLIC2
# 9     CCL18   RPL41   STAT1  TREM2    BCL2A1    CORO1A    PPIF   GPR157
#
#           8        9
# 0      GZMB   RIPOR2
# 1    LILRA4     LYST
# 2    JCHAIN   POU2F2
# 3      IRF4  CLEC12A
# 4      IRF7     VSIR
# 5     PLAC8     FCN1
# 6     ITM2C    LRRK2
# 7  C12orf75     MNDA
# 8     SMPD3      FGR
# 9      UGCG  CCDC88C

# %%
pg_df = pd.read_table("./00.data/PanglaoDB_markers_27_Mar_2020.tsv")
##remove mouse specific genes
pg_df = pg_df[pg_df['species']!='Mm']
cell_markers = {}##cell_marker is dictionary that contains names of cell types and their marker genes
marker_list = []
for i in list(set(pg_df["cell type"].values.tolist())):
    genes = pg_df[pg_df["cell type"]==i]['official gene symbol'].values.tolist()
    ##only use cell type with at least 5 genes and less than 300 genes
    if len(genes)>=5 and len(genes)<=300:
        cell_markers[i]=genes
        marker_list+= genes
marker_list = list(set(marker_list))
marker_list = [i for i in marker_list if i in adata.var.index]
len(marker_list)
# Out:
# 4045

# %%
ad = mac.copy()
ad = ad[:,marker_list]

##run MACA
ad, annotation = maca.singleMACA(ad=ad, cell_markers=cell_markers,
                                 res=[1,1.5,2],n_neis=[3,5,12])
# Out:
# (1637, 168)
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 22 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 12 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 10 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 30 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 17 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 14 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 35 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 24 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 17 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
ad.obs['Annotation']=np.array(annotation)
#map注释结果到leiden分类中
mac.obs['MACA']=ad.obs['Annotation']

# %%
sc.pl.umap(mac, color=['MACA'])

# %%
cluster = {
    'Monocytes':["CD14"],
    'Macrophage':["CD163","CCL7"],
    'M2 macrophage':["MRC1","CCL18"],
    'M1 macrophage':["IL7R","TNF"],
    'Dendritic cell':['CCL17',"CD68"]
}
sc.pl.stacked_violin(mac, cluster, groupby='cell type', swap_axes=False,save='Macrophage_marker.pdf')
# Out:
# WARNING: saving figure to file figures\stacked_violin_Macrophage_marker.pdf

# %%
def annot_prelim(adata_obj, barcode):
    curr_louvain_coarse = adata_obj.obs.loc[barcode,'cluster_0.8']
    if curr_louvain_coarse in ['2','3','5','6','9']:
        return('Macrophage')
    elif curr_louvain_coarse in ['0']:
        return('M2 macrophage')
    elif curr_louvain_coarse in ['4']:
        return('M1 macrophage')
    elif curr_louvain_coarse in ['7','8']:
        return('Dendritic cell')
    else:
        return('Monocytes')

# %%
mac.obs['barcode'] = mac.obs.index
mac.obs['cell type'] = mac.obs['barcode'].apply(lambda x: annot_prelim(mac,x))
mac.obs
# Out:
#                     n_genes          ID Sample   Tissue metastasis_status  \
# AAAGTCCCAGCCCAGT-1     4076  GSM5004180    PT1  Gastric           Primary
# AACAACCAGATGTAGT-1     3972  GSM5004180    PT1  Gastric           Primary
# AACAAGAAGCCTTTGA-1     2720  GSM5004180    PT1  Gastric           Primary
# AACACACCAACGGTAG-1     4222  GSM5004180    PT1  Gastric           Primary
# AAGACAAGTAGAATAC-1     2399  GSM5004180    PT1  Gastric           Primary
# ...                     ...         ...    ...      ...               ...
# TGTAACGAGTCCGCCA-1     3625  GSM5004189    Li2    Liver        Metastasis
# TGTAGACCATGCGGTC-1     1419  GSM5004189    Li2    Liver        Metastasis
# TTCCAATAGCCTCACG-1     4649  GSM5004189    Li2    Liver        Metastasis
# TTCTTCCTCGTGAGAG-1     1365  GSM5004189    Li2    Liver        Metastasis
# TTTGATCTCTTCGGTC-1     4295  GSM5004189    Li2    Liver        Metastasis
#
#                     percent_mito batch  n_counts  log_counts  doublet_scores  \
# AAAGTCCCAGCCCAGT-1      0.058936     0   17256.0    9.755916        0.235772
# AACAACCAGATGTAGT-1      0.095205     0   24673.0   10.113464        0.134718
# AACAAGAAGCCTTTGA-1      0.073280     0   10535.0    9.262459        0.103586
# AACACACCAACGGTAG-1      0.081000     0   24395.0   10.102134        0.196554
# AAGACAAGTAGAATAC-1      0.079118     0   13284.0    9.494315        0.092087
# ...                          ...   ...       ...         ...             ...
# TGTAACGAGTCCGCCA-1      0.040241     8   18613.0    9.831615        0.118607
# TGTAGACCATGCGGTC-1      0.199945     8    3666.0    8.206857        0.069822
# TTCCAATAGCCTCACG-1      0.043896     8   25583.0   10.149683        0.132785
# TTCTTCCTCGTGAGAG-1      0.097162     8    3911.0    8.271548        0.289221
# TTTGATCTCTTCGGTC-1      0.078985     8   16674.0    9.721606        0.240367
#
#                     ...  cluster_0.9 cluster_1.0 cluster_1.1 cluster_1.2  \
# AAAGTCCCAGCCCAGT-1  ...            5           5           6           6
# AACAACCAGATGTAGT-1  ...            7           7           7           8
# AACAAGAAGCCTTTGA-1  ...            4           6           5           4
# AACACACCAACGGTAG-1  ...            5           5           6           6
# AAGACAAGTAGAATAC-1  ...            4           6           5           4
# ...                 ...          ...         ...         ...         ...
# TGTAACGAGTCCGCCA-1  ...            5           5          11          11
# TGTAGACCATGCGGTC-1  ...            8           8           8           7
# TTCCAATAGCCTCACG-1  ...            5           5          11          11
# TTCTTCCTCGTGAGAG-1  ...            4           6           5           4
# TTTGATCTCTTCGGTC-1  ...            5           5           6           6
#
#                    cluster_1.3 cluster_1.4 cluster_1.5             MACA  \
# AAAGTCCCAGCCCAGT-1           6           6           6  Dendritic cells
# AACAACCAGATGTAGT-1           7           8           7  Dendritic cells
# AACAAGAAGCCTTTGA-1           5           4           4        Monocytes
# AACACACCAACGGTAG-1           7           8           7  Dendritic cells
# AAGACAAGTAGAATAC-1           5           4           4        Monocytes
# ...                        ...         ...         ...              ...
# TGTAACGAGTCCGCCA-1          12          12          13  Dendritic cells
# TGTAGACCATGCGGTC-1           8           7           8      Macrophages
# TTCCAATAGCCTCACG-1          12          12          13        Monocytes
# TTCTTCCTCGTGAGAG-1           5           4           4        Monocytes
# TTTGATCTCTTCGGTC-1           6           6           6      Macrophages
#
#                                barcode       cell type
# AAAGTCCCAGCCCAGT-1  AAAGTCCCAGCCCAGT-1      Macrophage
# AACAACCAGATGTAGT-1  AACAACCAGATGTAGT-1  Dendritic cell
# AACAAGAAGCCTTTGA-1  AACAAGAAGCCTTTGA-1   M1 macrophage
# AACACACCAACGGTAG-1  AACACACCAACGGTAG-1      Macrophage
# AAGACAAGTAGAATAC-1  AAGACAAGTAGAATAC-1   M1 macrophage
# ...                                ...             ...
# TGTAACGAGTCCGCCA-1  TGTAACGAGTCCGCCA-1      Macrophage
# TGTAGACCATGCGGTC-1  TGTAGACCATGCGGTC-1      Macrophage
# TTCCAATAGCCTCACG-1  TTCCAATAGCCTCACG-1      Macrophage
# TTCTTCCTCGTGAGAG-1  TTCTTCCTCGTGAGAG-1   M1 macrophage
# TTTGATCTCTTCGGTC-1  TTTGATCTCTTCGGTC-1      Macrophage
#
# [1637 rows x 30 columns]

# %%
sc.settings.set_figure_params(dpi=100,dpi_save=600,figsize=(6,6))
mac.obs["cell type"] =mac.obs["cell type"].astype('category')
sc.pl.umap(mac, color='cell type',add_outline=True, legend_loc='right margin',
               legend_fontsize=10, legend_fontoutline= 1,frameon= True,save='Macrophage.pdf')
# Out:
# WARNING: saving figure to file figures\umapMacrophage.pdf
